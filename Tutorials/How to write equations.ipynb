# %%
from IPython.display import display, Math

# %%
display('4 + 3 = ' + str(4+3))
# Out:
# '4 + 3 = 7'

# %%
x = 4
y = 5

display(Math('%g+%g = %g'%(x,y,x+y)))
# Out:
# $\displaystyle 4+5 = 9$

# %%
y = 17
display(Math('\\frac{4}{5}'))
# Out:
# $\displaystyle \frac{4}{5}$

# %%
display(Math('%g \\times %g = %g' %(x,y, x*y)))
# Out:
# $\displaystyle 4 \times 17 = 68$

# %%
x = 7
y = -2
z = 5

display(Math('3x(4+y)=43'))
display(Math('-y - \\frac{x+3}{z} = 42'))
# Out:
# $\displaystyle 3x(4+y)=43$
# $\displaystyle -y - \frac{x+3}{z} = 42$
