# %%
from IPython.display import display, Math
import numpy as np
import sympy as sym
sym.init_printing()

# %%
x,y = sym.symbols('x,y')
mu,alpha,sigma = sym.symbols('mu,alpha,sigma')

# %%
x
# Out:
# x

# %%
x + 4
# Out:
# x + 4

# %%
display(x**y)
display(x/y)
# Out:
#  y
# x
# x
# ─
# y

# %%
display(np.sqrt(2))
display(sym.sqrt(2))
# Out:
# 1.4142135623730951
# √2

# %%
display(Math('y \\times x^2'))
# Out:
# $\displaystyle y \times x^2$

# %%
display(Math('\\sqrt{4}x'))
# Out:
# $\displaystyle \sqrt{4}x$

# %%
display(Math('\\sqrt{x}\\sqrt{x}'))
# Out:
# $\displaystyle \sqrt{x}\sqrt{x}$

# %%
display((Math('4 + 3 = 7')))
# Out:
# $\displaystyle 4 + 3 = 7$

# %%
display(Math('a_{nm} = y \\times x^{2 \\times 3}'))
# Out:
# $\displaystyle a_{nm} = y \times x^{2 \times 3}$

# %%
display(Math('\\text{The answer to this equation is } \\frac{1+x}{2v-s^{t+4r}}'))
# Out:
# $\displaystyle \text{The answer to this equation is } \frac{1+x}{2v-s^{t+4r}}$

# %% [markdown]
# The answer to this equation is: $\frac{1+x}{2v-s^{t+4r}}$

# %%
expr = sym.exp(mu-alpha)**2 / (2*sigma**2)

# %%
display(expr)
# Out:
#  -2⋅α + 2⋅μ
# ℯ
# ───────────
#        2
#     2⋅σ

# %%
expr = x + 4 + 2*y
display(expr)

expr.subs({x: -4, y: 3})
# Out:
# x + 2⋅y + 4
# 6

# %%
expr = 3/x
display(Math(sym.latex(expr)))
# Out:
# $\displaystyle \frac{3}{x}$

# %%
display(Math(sym.latex(sym.sympify('3/4'))))
# Out:
# $\displaystyle \frac{3}{4}$

# %%
expr = x**2 + 4
for i in range(-2, 3):
    ans = expr.subs(x,i)
    display(Math('\\text{with } x= %g, x^2+4 \\quad \\Rightarrow \\quad %g^2+4 = %g' %(i, i, ans)))
# Out:
# $\displaystyle \text{with } x= -2, x^2+4 \quad \Rightarrow \quad -2^2+4 = 8$
# $\displaystyle \text{with } x= -1, x^2+4 \quad \Rightarrow \quad -1^2+4 = 5$
# $\displaystyle \text{with } x= 0, x^2+4 \quad \Rightarrow \quad 0^2+4 = 4$
# $\displaystyle \text{with } x= 1, x^2+4 \quad \Rightarrow \quad 1^2+4 = 5$
# $\displaystyle \text{with } x= 2, x^2+4 \quad \Rightarrow \quad 2^2+4 = 8$
